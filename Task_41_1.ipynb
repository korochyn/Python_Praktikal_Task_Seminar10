# %% [markdown]
# <a href="https://colab.research.google.com/github/korochyn/Python_Praktikal_Task_Seminar10/blob/main/Task_41_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  robot
# 2  human
# 3  human
# 4  robot

# %%
new_data = pd.get_dummies(data)
new_data.head()
# Out:
#    whoAmI_human  whoAmI_robot
# 0             0             1
# 1             0             1
# 2             1             0
# 3             1             0
# 4             0             1

# %% [markdown]
# Без метоода  pd.get.dummies() не получилось. Хотя идеи и были.
